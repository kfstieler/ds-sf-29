# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
import statsmodels.formula.api as smf

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
loansData = pd.read_excel('/Users/sachinkelkar/desktop/ds-sf-29/loansData.xls')

# %%
loansData.describe()
# Out:
# /Users/sachinkelkar/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Amount.Requested  Amount.Funded.By.Investors  Interest.Rate  \
# count       2500.000000                 2500.000000    2500.000000
# mean       51631.597200                12406.500000   12001.573236
# std        30053.345508                 7801.544872    7745.320754
# min           10.000000                 1000.000000      -0.010000
# 25%        26523.000000                 6000.000000    6000.000000
# 50%        50653.000000                10000.000000   10000.000000
# 75%        77580.500000                17000.000000   16000.000000
# max       104202.000000                35000.000000   35000.000000
#
#        Loan.Length        State     FICO.Range  Revolving.CREDIT.Balance  \
# count  2500.000000  2500.000000    2499.000000               2498.000000
# ...

# %%
cleanloanData = loansData.dropna()

# %%
cleanloanData.head()
# Out:
#    Amount.Requested  Amount.Funded.By.Investors  Interest.Rate  Loan.Length  \
# 0             81174                       20000        20000.0       0.0890
# 1             99592                       19200        19200.0       0.1212
# 2             80059                       35000        35000.0       0.2198
# 3             15825                       10000         9975.0       0.0999
# 4             33182                       12000        12000.0       0.1171
#
#   Loan.Purpose Debt.To.Income.Ratio   State Home.Ownership Monthly.Income  \
# 0    36 months   debt_consolidation  0.1490             SC       MORTGAGE
# 1    36 months   debt_consolidation  0.2836             TX       MORTGAGE
# 2    60 months   debt_consolidation  0.2381             CA       MORTGAGE
# 3    36 months   debt_consolidation  0.1430             KS       MORTGAGE
# 4    36 months          credit_card  0.1878             NJ           RENT
#
#    FICO.Range Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# ...

# %%
cleanloanData.corr()
# Out:
#                                 Amount.Requested  Amount.Funded.By.Investors  \
# Amount.Requested                        1.000000                    0.131659
# Amount.Funded.By.Investors              0.131659                    1.000000
# Interest.Rate                           0.173499                    0.969841
# Loan.Length                             0.247316                    0.331831
# State                                   0.242922                    0.081288
# FICO.Range                              0.004184                    0.391179
# Revolving.CREDIT.Balance                0.180891                    0.195942
# Inquiries.in.the.Last.6.Months          0.078517                    0.293365
# Employment.Length                       0.141231                   -0.029561
#
#                                 Interest.Rate  Loan.Length     State  \
# Amount.Requested                     0.173499     0.247316  0.242922
# ...

# %%
cleanloanData=cleanloanData.rename(columns = {'Amount.Funded.By.Investors':'AmountFunded'})

# %%
cleanloanData=cleanloanData.rename(columns = {'Amount.Requested':'AmountRequested'})

# %%
cleanloanData=cleanloanData.rename(columns = {'Interest.Rate':'InterestRate'})

# %%
cleanloanData=cleanloanData.rename(columns = {'Loan.Length':'LoanLength'})

# %%
cleanloanData.head()
# Out:
#    AmountRequested  AmountFunded  InterestRate  LoanLength Loan.Purpose  \
# 0            81174         20000       20000.0      0.0890    36 months
# 1            99592         19200       19200.0      0.1212    36 months
# 2            80059         35000       35000.0      0.2198    60 months
# 3            15825         10000        9975.0      0.0999    36 months
# 4            33182         12000       12000.0      0.1171    36 months
#
#   Debt.To.Income.Ratio   State Home.Ownership Monthly.Income  FICO.Range  \
# 0   debt_consolidation  0.1490             SC       MORTGAGE     6541.67
# 1   debt_consolidation  0.2836             TX       MORTGAGE     4583.33
# 2   debt_consolidation  0.2381             CA       MORTGAGE    11500.00
# 3   debt_consolidation  0.1430             KS       MORTGAGE     3833.33
# 4          credit_card  0.1878             NJ           RENT     3195.00
#
#   Open.CREDIT.Lines  Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# ...

# %%
cleanloanData.corr()
# Out:
#                                 AmountRequested  AmountFunded  InterestRate  \
# AmountRequested                        1.000000      0.131659      0.173499
# AmountFunded                           0.131659      1.000000      0.969841
# InterestRate                           0.173499      0.969841      1.000000
# LoanLength                             0.247316      0.331831      0.336830
# State                                  0.242922      0.081288      0.093679
# FICO.Range                             0.004184      0.391179      0.374377
# Revolving.CREDIT.Balance               0.180891      0.195942      0.185826
# Inquiries.in.the.Last.6.Months         0.078517      0.293365      0.261892
# Employment.Length                      0.141231     -0.029561     -0.067757
#
#                                 LoanLength     State  FICO.Range  \
# AmountRequested                   0.247316  0.242922    0.004184
# AmountFunded                      0.331831  0.081288    0.391179
# ...

# %%
lm = smf.ols(formula='AmountFunded ~ AmountRequested + InterestRate', data=cleanloanData).fit()
lm.params
# Out:
# Intercept          1105.540193
# AmountRequested      -0.009804
# InterestRate          0.983682
# dtype: float64

# %%
lm.rsquared
# Out:
# 0.94197279334939066

# %%
lm.pvalues
# Out:
# Intercept          1.420764e-34
# AmountRequested    1.836304e-14
# InterestRate       0.000000e+00
# dtype: float64

# %%
lm = smf.ols(formula='AmountFunded ~ AmountRequested + InterestRate + LoanLength', data=cleanloanData).fit()
lm.params
# Out:
# Intercept           843.383910
# AmountRequested      -0.010536
# InterestRate          0.979267
# LoanLength         2700.125428
# dtype: float64

# %%
lm.rsquared
# Out:
# 0.94215049001849427

# %%
lm.pvalues
# Out:
# Intercept          9.633571e-11
# AmountRequested    7.252000e-16
# InterestRate       0.000000e+00
# LoanLength         5.684919e-03
# dtype: float64

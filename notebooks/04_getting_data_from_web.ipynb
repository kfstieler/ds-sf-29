# %%
import sys
import requests     # how python goes onto the internet!
import re           # regex
from bs4 import BeautifulSoup # a python HTML parser (version 3)

# %%
# let's turn to stock prices
# http://finance.google.com/finance?q=aapl

# %%
symbol = 'aapl'

# %%
# Let's grab the raw html from the page
r = requests.get('http://finance.google.com/finance?q='+symbol) # the url of the google finance page goes in here

# %%
# b = BeautifulSoup(r.text, "html5lib") # create a beautifulsoup object
b = BeautifulSoup(r.text, 'html.parser') # try this line instead if you have problems

# %%
b.prettify() # will print the html nicely
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <script>\n   (function(){(function(){function e(a){this.t={};this.tick=function(a,c,b){var d=void 0!=b?b:(new Date).getTime();this.t[a]=[d,c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(e){}};this.tick("start",null,a)}var a,d;window.performance&&(d=(a=window.performance.timing)&&a.responseStart);var f=0<d?new e(d):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart;0<c&&d>=c&&(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0<c&&d>=c&&(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",\nd),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&&window.chrome.csi&&(a=Math.floor(window.chrome.csi().pageT),b&&0<c&&(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&&window.gtbExternal&&(a=window.gtbExternal.pageT()),null==a&&window.external&&(a=window.external.pageT,b&&0<c&&(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&&(window.jstiming.pt=a)}catch(g){}})();})();\n  </script>\n  <title>\n   Apple Inc.: NASDAQ:AAPL quotes &amp; news - Google Finance\n  </title>\n  <meta content="Get detailed financial information on Apple Inc. (NASDAQ:AAPL) including real-time stock quotes, historical charts &amp; financial news, all for free!" name="Description">\n   <meta content="IE=10" http-equiv="X-UA-Compatible">\n    <link href="http://www.google.com/finance?cid=22144" rel="canonical">\n     <link href="/finance/f/finance_us-1489929081.css" rel="stylesheet" type="text/css">\n      <link href="/_/scs/finance-static/_/ss/k=finance.a.-1ad9g7dkeydo6.L.W.O/d=0/rs=AGHGApFc6f3qtgX-rKpnovDqtgcuZ4H2Ng" rel="stylesheet" type="text/css">\n       <link href="/finance/favicon.ico" rel="icon" type="image/vnd.microsoft.icon">\n        <style>\n         #gbar,#guser{font-size:13px;padding-right:8px;padding-top:4px !important;}#gbar{padding-left:8px;height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}\n        </style>\n        <script>\n        </script>\n        <script>\n         function _rpt() {}\n      function _tck() {}\n        </script>\n        <script>\n         (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'create\', \'UA-40765809-1\', {\n      \'allowLinker\': true,\n      \'cookiePath\': \'/finance\'\n    });\n    ga(\'send\', \'pageview\');\n        </script>\n       </link>\n      </link>\n     </link>\n    </link>\n   </meta>\n  </meta>\n </head>\n <body>\n  <div class="fjfe-bodywrapper">\n   <div class="g-doc" id="fjfe-real-body">\n    <input id="hist_state" name="hist_state" style="display:none;" type="text">\n     <iframe class="invfr" id="hist_frame" name="hist_frame" tabindex="-1">\n     </iframe>\n     <iframe class="invfr" src="/_/scs/finance-static/_/js/k=finance.a.en_US.0md5hz5pgeA.O/m=b/rt=h/d=0/rs=AGHGApHi_3j1v_Z6n816dUrW-04N4o1Vbg" tabindex="-1">\n     </iframe>\n     <div id="gbar">\n      <nobr>\n       <a class="gb1" href="https://www.google.com/webhp?tab=ew">\n        Search\n       </a>\n       <a class="gb1" href="http://www.google.com/imghp?hl=en&amp;tab=ei">\n        Images\n       </a>\n       <a class="gb1" href="http://maps.google.com/maps?hl=en&amp;tab=el">\n        Maps\n       </a>\n       <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=e8">\n        Play\n       </a>\n       <a class="gb1" href="http://www.youtube.com/?tab= ...

# %%
# find all span tags
b.findAll('span')
# b.find_all('span') for bs4 users
# Out:
# [<span class="gbi" id="gbn"></span>,
#  <span class="gbf" id="gbf"></span>,
#  <span id="gbe"></span>,
#  <span class="fjfe-searchbox-button-wrapper"><span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span></span>,
#  <span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span>,
#  <span class="fjfe-recentquotes-duration">(<a href="//www.google.com/history/optout?hl=en">30 days</a>)</span>,
#  <span class="fjfe-chg-toggle">chg</span>,
#  <span class="fjfe-perc-toggle">%</span>,
#  <span class="pr">
#  <span id="ref_22144_l">109.99</span>
#  </span>,
#  <span id="ref_22144_l">109.99</span>,
#  <span class="ch bld"><span class="chg" id="ref_22144_c">+2.88</span>
#  <span class="chg" id="ref_22144_cp">(2.69%)</span>
#  </span>,
#  <span class="chg" id="ref_22144_c">+2.88</span>,
#  <span class="chg" id="ref_22144_cp">(2.69%)</span>,
#  <span class="bld" id="ref_22144_el">109.96</span>,
#  <span class="chr" id="ref_22144_ec">-0.03</span>,
#  <span class="chr" id="ref_22144_ecp">(-0.03%)</span>,
#  <span class="dis-large"><nobr>NASDAQ
#  real-time data -
#  <a class="dis-large" href="//www.google.com/help/stock_disclaimer.html#realtime">Disclaimer</a>
#  </nobr></span>,
#  <span class="settings-link">Settings</span>,
#  <span class="technicals-link">Technicals</span>,
#  <span style="white-space:nowrap;">
#  <img alt="Link to chart icon." class="linktochart-img SP_link" hight="9" src="/finance/s/m4C5KaofCbA/images/cleardot.gif" width="16"/>
#  <span class="linktochart-link">
#  Link to this view</span>
#  </span>,
#  <span class="linktochart-link">
#  Link to this view</span>,
#  <span class="chart-dis">Volume delayed by 15 mins.<br>Prices are not from all markets.<br>Sources include SIX.<br>
#  </br></br></br></span>,
#  <span class="id-related-edit-col linkbtn">Add or remove columns</span>]

# %%
# the pattern we recognized from the website
re_tag = re.compile("ref_\d+_l")

# %%
#this tag finds the tag with the price in it!!!!
span_tag = b.find('span', attrs={'id': re_tag}) 
# use find to return THE ONE AND ONLY span tags with an id that matches our regex
# use findAll to find all matches

# %%
quote = span_tag.text
quote
# Out:
# u'108.05'

# %%
##### EXERCISE #####
# Make a method  get_stock_price that takes in ANY stock ticker and grabs the current price
# If the stock ticker doesn't exist, return -1

# %%
def get_stock_price(ticker):
    response = requests.get("http://google.com/finance?q="+ticker)
    parser = BeautifulSoup(response.text, "html.parser")
    pattern = re.compile("ref_\d+_l")
    span_tag = parser.find("span", attrs={"id":pattern})
    if span_tag:
        return span_tag.text
    else:
        return -1

# %%
for ticker in ['ge', 'spy']:
    print get_stock_price(ticker)
# Out:
# 30.53
# 215.98

# %%
response = requests.get("http://www.nytimes.com/")
parser = BeautifulSoup(response.text, "html.parser")
for story in parser.findAll("h2", attrs={'class':'story-heading'}):
    print story.text
# Out:
# Vice President-Elect Tapped for Contacts in Washington
# Transition Briefing: Trump Shakes Up the Team 1:57 PM ET
# Trump Recruiting Among the Lobbyists He Once Denounced
# End the Filibuster or Preserve Tradition?
#
#                                     Talking Trump on the Staten Island Ferry
# On Staten Island, Pantsuit Nation Met Its Match
# The Women Who Helped Trump to Victory ...
# ... and Those With Dreams That Were Crushed
# Campuses Confront Hostile Acts Against Minorities
# A Sense of Whiplash About Affordable Care Act
# What Is Lost by Burying the Pacific Trade Deal?
# Meeting With Obama Was a ‘Great Honor,’ Trump Says
# Roy Cooper Holds Thin Lead Over Gov. Pat McCrory in North Carolina
# Extending the G.O.P. Winning Streak in Arizona
# Trump Lawyers Agree to Talks Over University Suit
# Full Election Results
#
# Denounce the Hate, Mr. Trump
# The Democrats Screwed Up
# The Glass Ceiling Holds
# David Plouffe: What I Got Wrong About the Election
# Glenn Beck: Don’t Move to Canada. Talk to the Other Side.
# Clinton’s Substantial Popular-Vote Win
# Thoughts for the Horrified
# The View From Trump Tower
# Resist Much
# ISIS Is Massacring Civilians as Troops Advance, U.N. Says
# Women Have Led Over 70 Countries. Why Not the U.S.?
# Currency Bans Agitate India
# Bottled Water Must Be Sent to Flint, Mich., Judge Orders
# Russia Prepares to Block LinkedIn After Court Ruling
# Taliban Strike German Consulate in Afghan City of Mazar-i-Sharif
# Paralyzed Monkeys Walk Again With Wireless Connection
# Twitter’s Chief Operating Officer to Step Down
# California Today: Why Californians Kept the Death Penalty
# 9 New Books We Recommend This Week
# A Big Life Change Is More Planning Than Magic
# In Megyn Kelly Book, New Details on Clash With Trump
# Teenager Seeks to Honor Veterans of War by Preserving Their Stories
# World (or at Least Brooklyn) Stops for Lost Dog
# Advocates for the Poor Push for Lower Transit Fares
#
# Trying Out Personal Shoppers for Free
#
#
# ‘We Should Get to Tell Our Own Stories First’
#
#
# Is Life Fair? Four Picture Books Say No
#
# America Needs a War on Terror Veterans Memorial
# Op-Ed: After Trump, Fear and Gloating in Pakistan
# Krugman: The Long Haul 10:40 AM ET
# Follow us on Twitter »
# The Rage of White, Christian America
# Letters: An American Muslim Woman’s Heartbreak
# My Liberal University Cemented My Vote for Trump
# Editorial: Voters Drive Sheriff Arpaio Out of Town
#
# Copy Edit Tihs!
#
#
# Good, Bad and Mad: Andrew Rosenthal on the Post-Election News
#
#
# Copy Edit Tihs!
#
#
# Play Today’s Puzzle
#
#
# Play Today’s Puzzle
#
#
# Come On Along With Us
#
# Stella McCartney Presents Her Men’s Wear Line
# America Needs a War on Terror Veterans Memorial
# Have Some Art With Your Handbag
# Book Review: ‘Swing Time,’ by Zadie Smith
# Editorial: Voters Drive Sheriff Arpaio Out of Town
# Online Retailers See the Appeal of an Actual Store
# Review: Ang Lee Turns His Eye on the Iraq War
# After Trump, Fear and Gloating in Pakistan
# Workout Gear for Not Breaking a Sweat
# In London, Plaques Mark the Noted and Notorious
# Letters: Moving On, After a Rancorous Election
# 36 Hours in Toronto
#
#
#             The Saturday Profile: How Zeng Fanzhi Became China’s Hottest Artist, and Why His Lawn Is So Green
#
#
#
#             What in the World: Jerusalem’s Latest Argument Over History Is About Fried Innards
#
#
#
#             Your Money: We Have a Retirement Savings Problem. Politicians Can Help.
#
#
#
#             Wall St. Is Mixed as Energy Companies Fall
#
#
#
#             Editorial: Denounce the Hate, Mr. Trump
#
#
#
#             David Brooks: The View From Trump Tower
#
#
#
#             California Today: California Today: Why Californians Kept the Death Penalty
#
#
#
#             The Women Who Helped Donald Trump to Victory
#
#
#
#             Russia Prepares to Block LinkedIn After Court Ruling
#
#
#
#             Streaming: Why Netflix Lets Movie Lovers Down, and What to Do About It
#
#
#
#             Review: Megyn Kelly Tells Tales Out of Fox News in Her Memoir, ‘Settle for More’
#
#
#
#             What It’s Like to Make It in Showbiz With Your Best Friend
#
#
#
#             What Will President Trump Do on Birth Control, Climate and Immigration?
#
#
#
#             On Washington: Hard Choice for Mitch McConnell: End the Filibuster or Preserve Tradition
#
#
#
#             Readers Reflect on Michelle Obama’s Path to the White House — and What’s Next
#
#
#
#             Stella McCartney Presents Her Men’s Wear Line
#
#
#
#             Review: In ‘Elle,’ Isabelle Huppert Subverts the Role of Rape Victim
#
#
#
#             Review: Oscar-Winner Ang Lee’s Super-High-Definition Take on the Iraq War
#
#
#
#             Big City: On Staten Island, Pantsuit Nation Met Its Match
#
#
#
#             Trump Tower, a Site That Drew Tourists, Now Draws Heavy Security
#
#
#
#             On Soccer: Before U.S. and Mexico Play, Fans Push for Respect in a Charged Atmosphere
#
#
#
#             Bartolo Colon Leaves Mets; Agrees to a Deal With the Braves
#
#
#
#             A Pasek and Paul Primer
#
#
#
#             6 Plays That Reckon With an Anxious America
#
#
#
#             Trump’s Climate Contrarian: Myron Ebell Takes On the E.P.A.
#
#
#
#             Canada’s Big Dams Produce Clean Energy, and High Levels of Mercury
#
#
#
#             Rosamond Bernier, Art Insider Who Turned Lectures Into Theater, Dies at 100
#
#
#
#             Charles Wolf Jr., Who Clashed With Pentagon Papers Leaker, Dies at 92
#
#
#
#             Critic's Notebook: A Rudderless Night, as News Networks Struggle With a Surprise Victory
#
#
#
#             For Stephen Colbert, a Very Uncomfortable Election Night
#
#
#
#             Well: Which Milk Is Most Nutritious: Soy, Cashew, Almond or Coconut?
#
#
#
#             A Lesson for India in a Fog So Thick It Could Kill a Cow
#
#
#
#             Frugal Traveler: An American Rain Forest and Its Charming Neighbor
#
#
#
#             Explorer: Rapa Nui Is Remote. And Then There’s Its Isolated North Coast
#
#
#
#             By the Book: Megyn Kelly: By the Book
#
#
#
#             Books of The Times: Review: ‘They Can’t Kill Us All’ Tallies the Unarmed Black Men Shot by Police
#
#
#
#             Rezoning Plan to Remake 3 Upper West Side Schools Will Proceed, City Says
#
#
#
#             Plight of the Public U: How the University of Alabama Became a National Player
#
#
#
#             Hungry City: At Thursday Kitchen, Cocktails Glow and Korean Food Relaxes
#
#
#
#             What to Cook: What to Cook This Weekend
#
#
#
#             Editorial: Imagining America on Nov. 9
#
#
#
#             Frank Bruni: Why This Election Terrifies Me
#
#
#
#             360 View: Going Down the Pinterest Rabbit Hole
#
#
#
#             Calculator: Where to Find Two-Bedrooms in New York City
#
#
#
#             Economic View: Handouts With a Twist: Rebuilding America’s Infrastructure
#
#
#
#             Fiscal Policy: The Trump Administration Could Test Whether Deficits Help the Economy
#
#
#
#             Notebook: Trump and the Presidential Look
#
#
#
#             The Design Issue: Inside the 21st-Century Craze for Redesigning Everything
#
#
#
#             A Vehicle’s Sound System Can Be a Matter of Life and Death
#
#
#
#             Driven: Video Review: Buick Envision, a Crossover With a Chinese Heritage
#
#
#
#             A Love Letter to Drinking in Bars
#
#
#
#             Rick Owens’s Monumental — if Not Entirely Cozy — Furniture
#
#
#
#             Copy Edit Tihs!
#
#
#
#             1964 | ‘Rightists Buoyed by the Election’
#
# Going Down the Pinterest Rabbit Hole
# Search for Homes for Sale or Rent
# Sell Your Home

# %%
response = requests.get("https://en.wikipedia.org/wiki/Wikipedia:Today%27s_featured_article/March_20,_2010")
parser = BeautifulSoup(response.text, "html.parser")

# %%
parser.find('div', attrs={'id':'mw-content-text'}).text
# Out:
# u'function mfTempOpenSection(id){var block=document.getElementById("mf-section-"+id);block.className+=" open-block";block.previousSibling.className+=" open-block";}\nNew York State Route\xa0174 is a state highway in the county of Onondaga, located in Central New York, United States. The highway is 16.70 miles (26.88\xa0km) long and passes through mostly rural regions. Route\xa0174 begins at an intersection with NY\xa041 in Borodino, a hamlet of Spafford. It heads northward for most of its length, except for short distances in the villages of Marcellus and Camillus. The route ends at a junction with NY\xa05 west of Camillus, at the west end of the Route\xa05 Camillus bypass. Route\xa0174 is located along a large mapped sedimentary bedrock unit, known as the Marcellus Formation. The formation is named for an outcrop found near the town of Marcellus, New York, during a geological survey in 1839. The road was first laid out in the early 19th century following the path of Nine Mile Creek, which connected several early settlements in Central New York. The northern half of the route, between the villages of Marcellus and Camillus, was later improved as a plank road in 1855 by a private corporation that collected tolls from travelers on the road. The state took over the maintenance of the road by the beginning of the 20th century. The former plank road and an extension south to Otisco Lake and southwest to Skaneateles Lake was first designated as Route\xa0174 in the 1930 state highway renumbering. (more...)\nRecently featured: Race Against Time: Searching for Hope in AIDS-Ravaged Africa \u2013 Nikolai Rimsky-Korsakov \u2013 Tom Crean\n\n\nArchive\nBy email\nMore featured articles...\n\n\n\n'
